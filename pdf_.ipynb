# %%
pip install PyPDF2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 10.9 MB/s eta 0:00:00
# ...

# %%
import PyPDF2

def extract_text_from_pdf(pdf_path):
    """
    Extracts text from all pages of a PDF file.
    """
    extracted_text = ""

    with open(pdf_path, "rb") as file:
        reader = PyPDF2.PdfReader(file)

        for page in reader.pages:
            page_text = page.extract_text()
            if page_text:
                extracted_text += page_text

    return extracted_text

# %%
pdf_path = "cv.pdf"
text = extract_text_from_pdf(pdf_path)

print(text[:1000])
# Out:
# Immidisetti Lakshmi Vrusha Sai Chatushva
# ♂phone+91-8309667885 —/envel⌢peimmidisettichatushva@gmail.com —/githubgithub.com/chatushva —/linkedin
# linkedin.com/in/chatushva-immidisetti
# Executive Summary
# Motivated 3rd-year B.Tech Computer Science Engineering student with hands-on experience in web development
# and basic cloud computing. Skilled in HTML, CSS, JavaScript, React.js, Node.js, REST APIs, MongoDB, SQL,
# Git, and GitHub. Seeking internship opportunities to apply problem-solving skills and build scalable web
# applications.
# Skills
# Programming Languages: Java, Python
# Web Technologies: HTML, CSS, JavaScript, React.js
# Backend Technologies: Node.js, Express.js, REST APIs
# Database: MongoDB, SQL
# Design Tools: Figma
# Version Control: Git, GitHub
# Core Concepts: Data Structures and Algorithms
# Projects
# Weather Application|HTML, CSS, JavaScript, REST API
# ...

# %%
from google import genai

# %%
client=genai.Client(api_key="AIzaSyDPd9SQmUXHCFQPI8-ephFriMrvKBc0_y0")

# %%
res = """
Detail-oriented B.Tech Computer Science Engineering student with hands-on experience in full-stack web development,
UI/UX design, and machine learning projects. Skilled in Java, Python, JavaScript, and modern web technologies, with
practical exposure through Smart India Hackathon, real-world problem solving, and academic projects. Demonstrated
ability to collaborate in teams, present solutions effectively, and build scalable, user-focused applications. Passionate about
software engineering, data-driven solutions, and continuous learning.
Technical Skills
Programming & Scripting: Java, Python, JavaScript, HTML, CSS
Tools/Platforms: VS Code, GitHub, Google Colab
Design & UI/UX: Figma, Wireframing, Prototyping
Core Concepts:Data Stuctures and Algorithms
Experience
Smart India Hackathon (SIH) – Team Member & Solution Presenter2025
"""

# %%
response=client.models.generate_content(
    model="gemini-2.5-flash",
    contents=(f'here is my context({text}),question:give rate for my res about resume')
)
print(response.text)
# Out:
# This is a strong resume for a 3rd-year B.Tech student seeking internships! It's well-organized, highlights relevant skills, and showcases good initiative.
#
# **Overall Rating: 4.5/5 stars (Excellent)**
#
# Here's a breakdown of strengths and areas for improvement:
#
# ---
#
# ### Strengths:
#
# 1.  **Clear and Concise Layout:** The resume is easy to read, with clear headings and bullet points.
# 2.  **Strong Executive Summary:** Clearly states your status, key skills, and objective.
# 3.  **Relevant Skills Section:** Well-categorized and lists all the important technologies and core concepts for web development and CS.
# 4.  **Good Project Descriptions:** Each project has a clear title, technologies used, and actionable bullet points explaining your contribution. The MERN stack project is a big plus.
# 5.  **Excellent Academic Record:** Your CGPA (9.1/10) and Intermediate score (913/1000) are very impressive and stand out.
# ...

# %%
# !pip install google-generativeai PyPDF2

# %%
import PyPDF2
from google import genai
from google.colab import files

client = genai.Client(
    api_key="AIzaSyBb3Q4DfvDnuH9225IVAwr-GFx4oLUdywI"
)

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-45e96a0a-b41a-4a4d-882b-cbcfecd9555f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-45e96a0a-b41a-4a4d-882b-cbcfecd9555f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
def extract_text_from_pdf(pdf_path):
    text = ""
    with open(pdf_path, "rb") as f:
        reader = PyPDF2.PdfReader(f)
        for page in reader.pages:
            text += page.extract_text() or ""
    return text

pdf_file = list(uploaded.keys())[0]
resume_text = extract_text_from_pdf(pdf_file)

print("Resume text preview:")
print(resume_text[:500])
# Out:
# Resume text preview:
# Immidisetti Lakshmi Vrusha Sai Chatushva
# ♂phone+91-8309667885 —/envel⌢peimmidisettichatushva@gmail.com —/githubgithub.com/chatushva —/linkedin
# linkedin.com/in/chatushva-immidisetti
# Executive Summary
# Motivated 3rd-year B.Tech Computer Science Engineering student with hands-on experience in web
# development. Skilled in HTML, CSS, JavaScript, React.js, Node.js, REST APIs, MongoDB, SQL, Git, and
# GitHub. Seeking internship opportunities to apply problem-solving skills and build scalable web applicatio

# %%
def parse_resume(resume_text):
    prompt = f"""
You are a resume parser.

Extract:
- Skills
- Experience summary
- Education
- Tools & technologies

Resume:
{resume_text}

Return in bullet points.
"""
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt
    )
    return response.text

# %%
parsed_resume = parse_resume(resume_text)

print("===== PARSED RESUME =====")
print(parsed_resume)
# Out:
# ===== PARSED RESUME =====
# Here's the extracted information from the resume:
#
# **Skills**
# *   HTML
# *   CSS
# *   JavaScript
# *   React.js
# *   Node.js
# *   Express.js
# *   REST APIs
# *   MongoDB
# *   SQL
# *   Git
# *   GitHub
# *   Java
# *   Python
# *   Figma
# *   Oops concepts
# *   UI/UX Design
# *   Wireframing
# *   User flows
# *   Accessibility design
# *   Mobile-friendly design
#
# **Experience summary**
# *   Developed a responsive weather application displaying real-time weather information using HTML, CSS, JavaScript, and a public REST Weather API.
# *   Built a full-stack food ordering web application using the MERN stack (MongoDB, Express.js, React.js, Node.js), implementing RESTful APIs and CRUD operations.
# *   Served as a UI/UX Designer for "Alumni Connectors" (MERN Web Application) at SIH 2025 – Internal Hackathon.
# ...

# %%
job_description = """
Looking for a Software Engineer with Python, Flask,
REST APIs, SQL, Git, and cloud basics.
"""

# %%
def parse_job_description(jd_text):
    prompt = f"""
Extract:
- Required skills
- Responsibilities
- Preferred qualifications

Job Description:
{jd_text}

Return in bullet points.
"""
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt
    )
    return response.text

parsed_jd = parse_job_description(job_description)
print(parsed_jd)
# Out:
# Here's the extraction:
#
# **Required skills:**
# *   Python
# *   Flask
# *   REST APIs
# *   SQL
# *   Git
# *   Cloud basics
#
# **Responsibilities:**
# *   (None explicitly stated in the provided text)
#
# **Preferred qualifications:**
# *   (None explicitly stated in the provided text)

# %%
def ats_match(parsed_resume, parsed_jd):
    prompt = f"""
You are an Applicant Tracking System.

Compare the resume and job description.

Resume:
{parsed_resume}

Job Description:
{parsed_jd}

Provide:
1. Match percentage (0-100)
2. Matching skills
3. Missing skills
4. Strengths
5. Improvement suggestions
"""
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt
    )
    return response.text

ats_result = ats_match(parsed_resume, parsed_jd)

print("===== ATS RESULT =====")
print(ats_result)
# Out:
# ===== ATS RESULT =====
# **ATS Analysis for Entry-Level Backend Developer**
#
# ---
#
# ### 1. Match Percentage
# **67%**
#
# ### 2. Matching Skills
# *   Python
# *   REST APIs
# *   SQL
# *   Git
#
# ### 3. Missing Skills
# *   Flask
# *   Cloud basics
#
# ### 4. Strengths
# *   **Strong Foundational Programming:** Proficient in Python, Java, and JavaScript, indicating a versatile programming base.
# *   **API & Database Expertise:** Demonstrates hands-on experience with REST APIs, MongoDB, and SQL, crucial for backend development.
# *   **Version Control:** Solid understanding and practical use of Git and GitHub.
# *   **Full-Stack Experience:** Experience with the MERN stack shows an ability to work across different layers of web applications, including backend development with Node.js and Express.js, which is transferable to other backend frameworks.
# ...
