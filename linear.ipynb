# %%
import pandas as pd

# %%
file = pd.read_csv("/content/Hours and Scores.csv")

# %%
file
# Out:
#    Unnamed: 0  Hours  Scores
# 0      2.5,21    2.5      21
# 1      5.1,47    5.1      47
# 2      3.2,27    3.2      27
# 3      8.5,75    8.5      75
# 4      3.5,30    3.5      30
# 5      1.5,20    1.5      20
# 6      9.2,88    9.2      88
# 7      5.5,60    5.5      60
# 8      8.3,81    8.3      81
# 9      2.7,25    2.7      25
# 10     7.7,85    7.7      85
# 11     5.9,62    5.9      62
# 12     4.5,41    4.5      41
# 13     3.3,42    3.3      42
# 14     1.1,17    1.1      17
# 15     8.9,95    8.9      95
# 16     2.5,30    2.5      30
# 17     1.9,24    1.9      24
# 18     6.1,67    6.1      67
# 19     7.4,69    7.4      69
# 20     2.7,30    2.7      30
# 21     4.8,54    4.8      54
# 22     3.8,35    3.8      35
# 23     6.9,76    6.9      76
# 24     7.8,86    7.8      86

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(file["Hours"],file["Scores"])

# %%
from sklearn.linear_model import LinearRegression

# %%
model =LinearRegression()

# %%
model.fit(file[["Hours"]],file["Scores"])
# Out:
# LinearRegression()

# %%
model.predict([[5]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([51.36269036])

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("/content/s.csv")
print(data.head())
# Out:
#    Study_Hours  Attendance  Previous_Score  Sleep_Hours  Final_Score
# 0            2          65              50            6           48
# 1            3          70              55            6           54
# 2            4          75              60            7           63
# 3            5          80              65            7           71
# 4            6          85              70            7           78

# %%
data
# Out:
#     Study_Hours  Attendance  Previous_Score  Sleep_Hours  Final_Score
# 0             2          65              50            6           48
# 1             3          70              55            6           54
# 2             4          75              60            7           63
# 3             5          80              65            7           71
# 4             6          85              70            7           78
# 5             7          90              75            8           85
# 6             8          92              80            8           90
# 7             1          60              45            5           40
# 8             2          68              52            6           50
# 9             3          72              58            6           57
# 10            4          78              62            7           65
# 11            5          82              68            7           73
# ...

# %%
X = data[['Study_Hours', 'Attendance', 'Previous_Score', 'Sleep_Hours']]
Y = data['Final_Score']

# %%
print(X.head())
print(Y.head())
# Out:
#    Study_Hours  Attendance  Previous_Score  Sleep_Hours
# 0            2          65              50            6
# 1            3          70              55            6
# 2            4          75              60            7
# 3            5          80              65            7
# 4            6          85              70            7
# 0    48
# 1    54
# 2    63
# 3    71
# 4    78
# Name: Final_Score, dtype: int64

# %%
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
new_student = [[6, 85, 70, 7]]
prediction = model.predict(new_student)

print("Predicted Final Score:", prediction[0])
# Out:
# Predicted Final Score: 77.44435686721559
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
